# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import decomposition
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
import seaborn as sns
from scipy.io import loadmat

# %%
X = loadmat('PaviaU.mat')['paviaU']
y = loadmat('PaviaU_gt.mat')['paviaU_gt']

# %%
print("X:", (X.shape))
print("y:", (y.shape))
# Out:
# X: (610, 340, 103)
# y: (610, 340)

# %%
X = X.reshape(X.shape[0]*X.shape[1], X.shape[2])
y = y.ravel()

# %%
print("X:", (X.shape))
print("y:", (y.shape))
# Out:
# X: (207400, 103)
# y: (207400,)

# %%
X = (X[y>0,:])
Y = (y[y>0])

# %%
print(X.shape)
print(Y.shape)
# Out:
# (42776, 103)
# (42776,)

# %%
X1 = pd.DataFrame(X)
corr = X1.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='BrBG', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(X1.columns),10)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
#ax.set_xticklabels(X1.columns)
#ax.set_yticklabels(X1.columns)
plt.show()
plt.savefig('corr_pu_final')

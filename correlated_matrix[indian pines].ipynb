# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import decomposition
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
import seaborn as sns
from scipy.io import loadmat

# %%
X = loadmat('Indian_pines_corrected.mat')['indian_pines_corrected']
y = loadmat('Indian_pines_gt.mat')['indian_pines_gt']

# %%
print("X:", (X.shape))
print("y:", (y.shape))
# Out:
# X: (145, 145, 200)
# y: (145, 145)

# %%
X = X.reshape(X.shape[0]*X.shape[1], X.shape[2])
y = y.ravel()

# %%
print("X:", (X.shape))
print("y:", (y.shape))
# Out:
# X: (21025, 200)
# y: (21025,)

# %%
X = (X[y>0,:])
Y = (y[y>0])

# %%
print(X.shape)
print(Y.shape)
# Out:
# (10249, 200)
# (10249,)

# %%
X1 = pd.DataFrame(X)
corr = X1.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='BrBG', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(X1.columns),20)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
#ax.set_xticklabels(X1.columns)
#ax.set_yticklabels(X1.columns)
plt.show()
plt.savefig('corr_ip_final')
